# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

# %% [markdown]
# ##  尋找matplotlib中可用字體
# 註：需知道中文字體的英文名稱

# %%
import matplotlib
[f.name for f in matplotlib.font_manager.fontManager.ttflist]
# Out:
# ['cmsy10',
#  'STIXSizeFourSym',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'cmr10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'cmb10',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'cmtt10',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'cmss10',
#  'STIXGeneral',
#  'cmmi10',
#  'STIXNonUnicode',
#  'DejaVu Sans Display',
#  'STIXSizeTwoSym',
#  'DejaVu Serif',
#  'STIXSizeFiveSym',
#  'DejaVu Serif Display',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'STIXSizeOneSym',
#  'DejaVu Sans Mono',
#  'STIXSizeFourSym',
#  'cmex10',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Mono',
#  'STIXSizeTwoSym',
#  'Noto Sans Kaithi',
#  'Andale Mono',
#  'Courier New',
#  'SignPainter',
#  'STIXSizeFiveSym',
#  'Noto Sans Old Persian',
#  '.New York',
#  'Hiragino Sans GB',
#  'Noto Sans Hatran',
#  'Tahoma',
#  'Noto Sans Thaana',
#  'Noto Sans Sundanese',
#  'Apple Braille',
#  'STIXIntegralsUpSm',
#  'Nanum Myeongjo',
#  'STIXSizeOneSym',
#  'Mishafi Gold',
#  'Noto Sans Brahmi',
#  'PSL Ornanong Pro',
#  'Noto Sans Tai Tham',
#  'Arial Narrow',
#  'Ayuthaya',
#  'Arial Black',
#  'HeadLineA',
#  'Yuanti SC',
#  'Tsukushi A Round Gothic',
#  'STIXIntegralsUp',
#  'Noto Sans New Tai Lue',
#  'Lantinghei SC',
#  'Noto Sans Old South Arabian',
#  'Noto Sans PhagsPa',
#  '.SF Hebrew',
#  'Bangla Sangam MN',
#  'Apple Braille',
#  'STIX Two Math',
#  'Times New Roman',
#  'Noto Sans Khojki',
#  'Noto Sans Javanese',
#  'Nanum Gothic',
#  'LingWai SC',
#  'BM Hanna 11yrs Old',
#  'Kefa',
#  'Menlo',
#  'STIXSizeThreeSym',
#  'Corsiva Hebrew',
#  'Apple SD Gothic Neo',
#  'Thonburi',
#  'Raanana',
#  'Skia',
#  'Hannotate SC',
#  'STIXIntegralsUpD',
#  'Courier New',
#  '.Keyboard',
#  'Hiragino Maru Gothic Pro',
#  'Sathu',
#  '?????1',
#  'Publico Text',
#  'Georgia',
#  'Noto Sans Inscriptional Pahlavi',
#  'DecoType Naskh',
#  'Nanum Brush Script',
#  'Myanmar MN',
#  'Bodoni 72 Smallcaps',
#  'Noto Sans Mandaic',
#  'Devanagari Sangam MN',
#  'Noto Sans Lepcha',
#  'LiHei Pro',
#  'Malayalam Sangam MN',
#  'STIXIntegralsUpSm',
#  'PCMyungjo',
#  'STIXGeneral',
#  'Noto Serif Myanmar',
#  'Kai',
#  'Noto Sans Linear B',
#  'Telugu Sangam MN',
#  'Bradley Hand',
#  'Avenir',
#  '.Zither Tamil',
#  'Oriya MN',
#  'Noto Sans Old Italic',
#  'Noto Sans Newa',
#  'Sinhala MN',
#  'STIXGeneral',
#  'Noto Sans Tirhuta',
#  'Arial Hebrew',
#  '.SF Compact',
#  'Georgia',
#  'STIXVariants',
#  'Wingdings 2',
#  'PingFang HK',
#  'YuKyokasho Yoko',
#  'Noto Sans Carian',
#  'Wingdings 3',
#  'Avenir Next',
#  'PT Mono',
#  'Copperplate',
#  'Kohinoor Devanagari',
#  'Big Caslon',
#  'Bodoni Ornaments',
#  'STIXSizeThreeSym',
#  'YuGothic',
#  'Noto Sans Batak',
#  'Chalkboard SE',
#  'Hiragino Sans',
#  'Apple Braille',
#  'Noto Sans Vai',
#  'Wawati SC',
#  '.SF Compact Rounded',
#  'Noto Sans Mahajani',
#  'Zapf Dingbats',
#  'Hiragino Sans CNS',
#  'Gurmukhi Sangam MN',
#  'Osaka',
#  '.SF Georgian Rounded',
#  'Noto Sans Wancho',
#  'Geneva',
#  'Helvetica',
#  'Hiragino Sans',
#  'Klee',
#  'Palatino',
#  'Oriya Sangam MN',
#  'Yuppy TC',
#  'AppleMyungjo',
#  'Hiragino Sans',
#  '.SF Soft Numeric',
#  'Savoye LET',
#  'Verdana',
#  'Bodoni 72 Oldstyle',
#  'STIXNonUnicode',
#  'Noto Sans Manichaean',
#  'Trattatello',
#  'Kohinoor Bangla',
#  'Myanmar Sangam MN',
#  '.DecoType Nastaleeq Urdu UI',
#  'Noto Sans Glagolitic',
#  'Kohinoor Telugu',
#  'STIXIntegralsD',
#  'Khmer MN',
#  'System Font',
#  'Lao Sangam MN',
#  'Superclarendon',
#  '.SF NS Mono',
#  'Charter',
#  'Noto Sans Canadian Aboriginal',
#  'Noto Sans Pahawh Hmong',
#  'STIXSizeFourSym',
#  'Papyrus',
#  'Noto Sans Cham',
#  'Apple LiGothic',
#  'Baoli SC',
#  'Euphemia UCAS',
#  'Trebuchet MS',
#  'Noto Sans Phoenician',
#  'Noto Sans Syloti Nagri',
#  'Helvetica Neue',
#  'Chalkboard',
#  'BM Hanna Pro',
#  'Wawati TC',
#  'Times',
#  'Krungthep',
#  'Avenir Next Condensed',
#  'Trebuchet MS',
#  'Heiti TC',
#  'STIXNonUnicode',
#  'STIXIntegralsUp',
#  'Noto Sans Hanunoo',
#  'InaiMathi',
#  'Gujarati MT',
#  'BIZ UDGothic',
#  'Noto Sans Lydian',
#  'Noto Sans Pau Cin Hau',
#  'Noto Sans Meroitic',
#  'Brush Script MT',
#  'Hiragino Sans',
#  'STIXGeneral',
#  'LingWai TC',
#  'Noto Sans Egyptian Hieroglyphs',
#  'Noto Sans Inscriptional Parthian',
#  'Hiragino Sans',
#  'Silom',
#  'Noto Sans Lisu',
#  'STIXIntegralsSm',
#  'PT Serif',
#  'STIXNonUnicode',
#  'Noto Sans Yi',
#  'Noto Sans Multani',
#  'Futura',
#  '.SF Compact',
#  'Seravek',
#  'Muna',
#  'Toppan Bunkyu Mincho',
#  'PT Sans',
#  'Publico Headline',
#  'Verdana',
#  'Damascus',
#  'Arial Unicode MS',
#  'Noto Sans Chakma',
#  'Noto Sans Sharada',
#  '.New York',
#  'Plantagenet Cherokee',
#  'Athelas',
#  'STIXNonUnicode',
#  'Noto Sans Bassa Vah',
#  'Gujarati Sangam MN',
#  'STIXGeneral',
#  'Trebuchet MS',
#  'American Typewriter',
#  'Osaka',
#  '.ThonburiUI',
#  'Noto Sans Marchen',
#  'Noto Sans Osage',
#  '.SF Georgian',
#  'BM Dohyeon',
#  'STIXIntegralsSm',
#  'Hiragino Sans',
#  'Snell Roundhand',
#  'Hiragino Sans',
#  'Wingdings',
#  'KufiStandardGK',
#  'SimSong',
#  'Tsukushi B Round Gothic',
#  'Kohinoor Gujarati',
#  'Noto Sans Oriya',
#  'DFGangBiW2-B5',
#  'BM Kirang Haerang',
#  'Arial',
#  'STIXSizeTwoSym',
#  'Bangla MN',
#  'YuMincho',
#  'Toppan Bunkyu Midashi Gothic',
#  'Noto Sans Bhaiksuki',
#  'Apple Braille',
#  'Optima',
#  'DIN Alternate',
#  'Gurmukhi MN',
#  'Noto Sans Tai Viet',
#  'Sana',
#  'Toppan Bunkyu Midashi Mincho',
#  'STIXSizeOneSym',
#  'Noto Sans Duployan',
#  'Heiti TC',
#  'Noto Sans Warang Citi',
#  'Noto Sans Takri',
#  'Hoefler Text',
#  'Noto Sans Gunjala Gondi',
#  'Microsoft Sans Serif',
#  'Tamil Sangam MN',
#  'Noto Sans Samaritan',
#  'Noto Sans Lycian',
#  '?????2',
#  'Academy Engraved LET',
#  'BM Jua',
#  'Geeza Pro',
#  'STIX Two Text',
#  'Noteworthy',
#  'Apple Chancery',
#  'Noto Sans Tifinagh',
#  'Shree Devanagari 714',
#  'Didot',
#  'BM Hanna Air',
#  'Noto Sans Psalter Pahlavi',
#  'Verdana',
#  'Noto Serif Balinese',
#  'Apple Symbols',
#  'Noto Sans Palmyrene',
#  'Times New Roman',
#  'Iowan Old Style',
#  'Arial',
#  'Times New Roman',
#  'Mukta Mahee',
#  'Noto Sans Adlam',
#  'Noto Sans Old North Arabian',
#  'Noto Sans Old Hungarian',
#  'Telugu MN',
#  'Noto Sans Cypriot',
#  'Noto Sans Armenian',
#  'STIXSizeFourSym',
#  'Party LET',
#  '.SF Camera',
#  'Noto Sans Gothic',
#  'Baghdad',
#  '.SF Hebrew Rounded',
#  'Herculanum',
#  'Beirut',
#  'Rockwell',
#  'Mshtakan',
#  'Noto Sans Modi',
#  'Georgia',
#  'Noto Sans Mende Kikakui',
#  'Arial',
#  'Hiragino Mincho ProN',
#  'Trebuchet MS',
#  'Arial Narrow',
#  'Noto Sans Cuneiform',
#  'Kaiti SC',
#  'Georgia',
#  'Songti SC',
#  'Noto Sans Masaram Gondi',
#  'STIXIntegralsD',
#  'Hei',
#  'Marion',
#  'Lucida Grande',
#  'Noto Serif Ahom',
#  'Khmer Sangam MN',
#  'STIX Two Text',
#  'Al Tarikh',
#  'HanziPen SC',
#  'Gurmukhi MT',
#  'BM Yeonsung',
#  'Times New Roman',
#  'Hoefler Text',
#  'Malayalam MN',
#  'Noto Sans Tai Le',
#  'Gill Sans',
#  'Mishafi',
#  'Al Bayan',
#  'Diwan Thuluth',
#  'STFangsong',
#  'Sinhala Sangam MN',
#  'Waseem',
#  'ITF Devanagari',
#  'Noto Sans Ugaritic',
#  'YuGothic',
#  'Yuppy SC',
#  'Phosphate',
#  'PT Serif Caption',
#  'Noto Sans Coptic',
#  'Noto Sans Myanmar',
#  'Noto Sans Hanifi Rohingya',
#  'Farah',
#  'Noto Sans Avestan',
#  'Tahoma',
#  'Noto Sans Khudawadi',
#  'Tamil MN',
#  'GungSeo',
#  'Noto Sans NKo',
#  'Noto Sans Bamum',
#  'Devanagari MT',
#  'Symbol',
#  'Diwan Kufi',
#  'System Font',
#  'Cochin',
#  'Noto Sans Kannada',
#  '.SF Arabic',
#  'PilGi',
#  'LiSong Pro',
#  '.SF NS Mono',
#  'Noto Sans Siddham',
#  'Noto Sans Caucasian Albanian',
#  'Noto Sans Kharoshthi',
#  'Noto Sans Sora Sompeng',
#  'Al Nile',
#  'DIN Condensed',
#  'Monaco',
#  'Comic Sans MS',
#  'Noto Sans Limbu',
#  'Courier New',
#  'Noto Serif Yezidi',
#  'Bodoni 72',
#  'Arial Narrow',
#  'Noto Nastaliq Urdu',
#  'Toppan Bunkyu Gothic',
#  'Apple Braille',
#  'STIXVariants',
#  'Kannada MN',
#  'Noto Serif Hmong Nyiakeng',
#  'Luminari',
#  'Hiragino Sans',
#  'BIZ UDMincho',
#  'Noto Sans Rejang',
#  'STIXIntegralsUpD',
#  'Noto Sans Tagalog',
#  'Noto Sans Mro',
#  'Noto Sans Meetei Mayek',
#  'Libian SC',
#  '.Zither Malayalam',
#  'Noto Sans Mongolian',
#  'Noto Sans Linear A',
#  'Noto Sans Old Permic',
#  'Noto Sans Miao',
#  'Hiragino Sans',
#  '.SF NS Rounded',
#  'Sukhumvit Set',
#  '.SF Armenian Rounded',
#  'Xingkai SC',
#  '.SF Arabic Rounded',
#  'Noto Sans Buginese',
#  'Noto Sans Old Turkic',
#  'Arial Unicode MS',
#  'Apple LiSung',
#  'Courier',
#  'Galvji',
#  'Noto Sans Nabataean',
#  'Noto Sans Buhid',
#  'Arial Rounded MT Bold',
#  'Courier New',
#  'BiauKaiHK',
#  '.Zither India',
#  'Noto Sans Imperial Aramaic',
#  'Impact',
#  'STHeiti',
#  'Noto Sans Elbasan',
#  'Farisi',
#  'Noto Sans Ol Chiki',
#  'Noto Sans Syriac',
#  'Noto Sans Osmanya',
#  'Verdana',
#  'Chalkduster',
#  '.SF Armenian',
#  'Arial',
#  '.Aqua Kana',
#  'Marker Felt',
#  'Nadeem',
#  '.CJK Symbols Fallback HK',
#  'Hiragino Sans',
#  'Comic Sans MS',
#  'Lao MN',
#  'Noto Sans Saurashtra',
#  'Kailasa',
#  'Noto Sans Tagbanwa',
#  'Kannada Sangam MN',
#  'Baskerville',
#  'Noto Sans Kayah Li',
#  'STHeiti',
#  'Zapfino',
#  'Webdings',
#  'AppleGothic',
#  'New Peninim MT',
#  'Arial Narrow',
#  'Kokonor']

# %% [markdown]
# ## 測試中文字體Notes:
# ### Mac可用字體：SimHei
# ### Windows 7可用字體：Microsoft YaHei
# ### Windows 10 可用字體：Microsoft JhengHei、DFKai-SB

# %% [markdown]
# # 方法一：更改 plt.rcParams['font.sans-serif'] 設定
# ## Matplotlib example

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
plt.rcParams['font.sans-serif'] = ['STHeiti']  # macbook 可用：Heiti TC, Arial Unicode MS, STHeiti


plt.plot((1,2,3),(4,3,-1))
plt.title("聲量圖")
plt.ylabel("文章數量")
plt.xlabel("品牌名稱") 
plt.show()

# %% [markdown]
# ## Seaborn example (如果有使用 Matplotlib 就可以不用再設定 seaborn)

# %%
#from matplotlib.font_manager import FontProperties
import seaborn as sns
#sns.set(font=['sans-serif']) 
#sns.set_style("whitegrid",{"font.sans-serif":['Microsoft JhengHei']})
cities_counter = [('好棒', 285), ('給我', 225), ('不要', 163), ('細柔', 136), ('吃飯', 130), ('小小', 124), ('深圳', 88), ('温州', 67), ('小知', 66), ('大之', 45)]
sns.set_color_codes("pastel")
sns.barplot(x=[k for k, _ in cities_counter[:10]], y=[v for _, v in cities_counter[:10]])
# Out:
# <Axes: >

# %% [markdown]
# # 方法二：更改 plt.rcParams['font.family'] 設定

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

fig = plt.figure(figsize=(6,4))
x = [1,2,3,4,5]
y = [123,432,823,192,12]

plt.rcParams['font.family']='STHeiti' #使用中文字體（黑體）

plt.bar(x,y,align='center')
plt.title('中文標題') #標題名稱
plt.xlabel('X軸') #X軸名稱
plt.ylabel('Y軸') #Y軸名稱
plt.xticks(x, ['刻度A','刻度B','刻度C','刻度D','刻度E']) #X軸刻度名稱

plt.show()

# %% [markdown]
# # 方法三：每次作圖使用特定字體

# %%
font1 = {'fontname':'STHeiti'}
font2 = {'fontname':'Heiti TC'}
font3 = {'fontname':'Arial Unicode MS'}

plt.bar(x,y,align='center')
plt.title('瀨戶字體標題',**font1, fontsize=18) #標題名稱
plt.xlabel('新宋字體X軸',**font2, fontsize=18) #X軸名稱
plt.ylabel('黑體Y軸',**font3, fontsize=18) #Y軸名稱
plt.show()

# %% [markdown]
# # 方法四、自訂字體型式
# ### 下載`.ttf`字體檔，直接指定字體路徑

# %%
from matplotlib.font_manager import FontProperties
font = FontProperties(fname='data/微軟正黑體.ttf')

plt.bar((1,2,3),(4,3,-1),align='center')
plt.title('微軟正黑體標題',fontproperties=font, fontsize=18) #標題名稱
plt.xlabel('微軟正黑體X軸',fontproperties=font, fontsize=18) #X軸名稱
plt.ylabel('微軟正黑體Y軸',fontproperties=font, fontsize=18) #Y軸名稱
plt.show()
